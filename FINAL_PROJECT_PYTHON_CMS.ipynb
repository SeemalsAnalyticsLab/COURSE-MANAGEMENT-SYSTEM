# %% [markdown]
# # ***DATA SEEKHO UNIVERSITY OF INNOVATION*** 📚🎓🏆

# %% [markdown]
# ### **COURSE MANAGEMENT SYSTEM** 📅🖥️📚

# %% [markdown]
# ![WhatsApp Image 2024-10-16 at 01.32.08_ae510eab.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Project Overview**:
#
# Course Management System for Data Seekho University of Innovation.
#
# At **Data Seekho University of Innovation**, founded by **Usama Hameed**, students manage various courses throughout the semester, each with unique requirements and activities.
#
# In this project, we will build a Course Management System that allows students to manage their courses efficiently.
#
# Each course will be represented as an object, featuring attributes such as course name, credits, and instructor.
#
# The project will implement the following object-oriented programming concepts:
#
# **Inheritance**:
#
#  A base Course class and specialized classes for programming and mathematics courses.
#
# **Polymorphism**:
#
#  Different courses will share methods that behave differently according to the course type.
#
# **Encapsulation**:
#
# We will protect course attributes while providing public methods to interact with them safely.
#
# **Abstraction**: Users can interact with courses without needing to know the underlying complexity.
#
# Let’s dive into the project, starting with an engaging implementation.

# %% [markdown]
# **Step-by-Step Implementation**
#
# **1. Defining the Base Class**: Course 📚
#
# **Task**: Create a basic blueprint for all courses.
#
# **What It Is**: A class called Course serves as a template for all courses at the university.
#
# **Why It Matters**: This class holds common information about every course, like its name, how many credits it has, and who teaches it.
#
# **How We Do It**: We write a constructor (__init__) to set up these details. We also create methods (functions inside the class) to get course information, syllabuses, and enroll students.

# %%
class Course:
    def __init__(self, course_name, credits, instructor):
        self.__course_name = course_name  # Course name
        self.__credits = credits            # Credits for the course
        self.__instructor = instructor      # Instructor name

    def get_course_info(self):             # Get course details
        return f"Course: {self.__course_name}, Credits: {self.__credits}, Instructor: {self.__instructor}"

    def get_syllabus(self):                 # Get the syllabus
        return f"Syllabus for {self.__course_name}: [Details of the syllabus]"

    def enroll_student(self, student_name): # Enroll a student in the course
        return f"{student_name} has been enrolled in {self.__course_name}."

# %% [markdown]
# **2. Inheritance**: Specialized Courses 💻
#
# **Task**: Create specific types of courses from the base course.
#
# **What It Is**: We make new classes for specific courses, like programming and mathematics, using the Course class as a starting point.
#
# **Why It Matters**: This allows us to add unique features to each course type while still keeping the common details from the Course class.
#
# **How We Do It**: We use the super() function to get the information from the Course class and then add specific attributes and methods for programming and mathematics courses.

# %%
class ProgrammingCourse(Course):
    def __init__(self, course_name, credits, instructor, programming_language):
        super().__init__(course_name, credits, instructor)  # Get details from Course
        self.programming_language = programming_language      # Specific to programming courses

    def get_practical_exercises(self):  # Get exercises for programming
        return f"Practical exercises for {self.programming_language} in {self.get_course_info()}."

class MathematicsCourse(Course):
    def __init__(self, course_name, credits, instructor, math_field):
        super().__init__(course_name, credits, instructor)  # Get details from Course
        self.math_field = math_field                            # Specific to math courses

    def get_formula_sheet(self):  # Get formula sheet for math
        return f"Formula sheet for {self.math_field} in {self.get_course_info()}."

# %% [markdown]
# **3. Polymorphism**: Different Behaviors ➗
#
# **Task**: Allow different courses to perform the same action in different ways.
#
# **What It Is**: We create a method called get_schedule() in both the programming and mathematics courses.
#
# **Why It Matters**: This lets us use the same method name but have it do different things depending on the course type.
#
# **How We Do It**: We define get_schedule() in each specialized class with different outputs.

# %%
class ProgrammingCourse(Course):
    # Other methods...
    def get_schedule(self):  # Schedule for programming courses
        return f"Schedule: Coding assignments and lab sessions for {self.get_course_info()}."

class MathematicsCourse(Course):
    # Other methods...
    def get_schedule(self):  # Schedule for math courses
        return f"Schedule: Theory lectures and problem-solving sessions for {self.get_course_info()}."

# %% [markdown]
# **4. Encapsulation**: Protecting Course Data 🎓
#
# **Task**: Keep some information private and provide ways to access it safely.
#
# **What It Is**: We use private attributes (marked with __) to protect sensitive information about courses, like their name and credits.
#
# **Why It Matters**: This ensures that no one can change these details directly without going through the right methods.
#
# **How We Do It**: We provide public methods to access and modify the private data safely.

# %%
class Course:
    def __init__(self, course_name, credits, instructor):
        self.__course_name = course_name  # Private attribute
        self.__credits = credits            # Private attribute
        self.__instructor = instructor      # Private attribute

    def get_course_info(self):             # Public method to get details
        return f"Course: {self.__course_name}, Credits: {self.__credits}, Instructor: {self.__instructor}"

# %% [markdown]
# **5. Abstraction** **bold text**: Simplifying Enrollment  🎭
#
# **Task**: Make it easy to enroll in a course without knowing the details.
#
# **What It Is**: We provide a method called enroll_student() that handles the enrollment process.
#
# **Why It Matters**: This allows students to enroll in a course without needing to know how the system works behind the scenes.
#
# **How We Do It**: The method takes the student’s name and confirms their enrollment.

# %%
class Course:
    # Other methods...
    def enroll_student(self, student_name): # Enroll a student in the course
        return f"{student_name} has been enrolled in {self.__course_name}."

# %% [markdown]
# **Example Usage** 💡
#
# **Task**: Show how to use the system.
#
# **What It Is**: Create instances of the courses and call their methods to see how they work.
#
# **Why It Matters**: This demonstrates how students can interact with the system to manage their courses.
#
# **How We Do It**: We create course objects and use their methods to get information, enroll students, and get schedules.*italicised text*

# %%
# Create instances of ProgrammingCourse and MathematicsCourse
prog_course = ProgrammingCourse("Python Programming", 4, "Danial", "Python")
math_course = MathematicsCourse("Calculus", 3, "Yousuf", "Calculus")

# Display course information
print(prog_course.info())
print(math_course.info())

# Display course schedules
print(prog_course.schedule())
print(math_course.schedule())

# Enroll students
print(prog_course.enroll("Aasma"))
print(math_course.enroll("jack"))

# Display practical exercises and formula sheets
print(prog_course.exercises())
print(math_course.formula_sheet())
# Out:
# Course: Python Programming, Credits: 4, Instructor: Danial
# Course: Calculus, Credits: 3, Instructor: Yousuf
# Schedule: Coding assignments for Course: Python Programming, Credits: 4, Instructor: Danial.
# Schedule: Lectures for Course: Calculus, Credits: 3, Instructor: Yousuf.
# Aasma enrolled in Python Programming.
# jack enrolled in Calculus.
# Exercises for Python in Course: Python Programming, Credits: 4, Instructor: Danial.
# Formula sheet for Calculus in Course: Calculus, Credits: 3, Instructor: Yousuf.

# %% [markdown]
# # **PROJECT SUMMARY** 📝
# **What We Did**: We built a Course Management System for Data Seekho University of Innovation.
#
# **How We Did It**: By using object-oriented programming concepts like inheritance, polymorphism, encapsulation, and abstraction.
#
# **Why It Matters:** This system helps students manage their courses easily and effectively.

# %% [markdown]
# **Conclusion** ✨
#
# This code represents a Course Management System for an imaginary university, specifically designed for Data Seekho University of Innovation. The system manages different courses, including programming and mathematics, allowing students to enroll, access course information, and view schedules.

# %% [markdown]
# # **PROJECT COMPLETED** ✅ 🎉
